# %% [markdown]
# # MLPClasssifier Dataset Alkhohol2

# %% [markdown]
# ### Masukkan librari

# %%
import numpy as np # linear algebra
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# ### Load File Dataset Iris Dengan CSV

# %%
df = pd.read_csv('https://raw.githubusercontent.com/AnggaCristanto/dataset/main/alkhohol-2.csv', sep = ';')
df
# Out:
#      0.799_0.201  0.799_0.201.1  0.700_0.300  0.700_0.300.1  0.600_0.400  \
# 0         -10.06         -10.62       -14.43         -18.31       -24.64
# 1          -9.69         -10.86       -16.73         -21.75       -28.47
# 2         -12.07         -14.28       -21.54         -27.92       -35.19
# 3         -14.21         -17.41       -25.91         -33.36       -41.29
# 4         -16.57         -20.35       -29.97         -37.84       -47.03
# ..           ...            ...          ...            ...          ...
# 120       -54.35         -56.09       -88.23         -90.54      -128.65
# 121       -56.14         -57.35       -90.74         -92.60      -132.16
# 122       -57.71         -58.37       -92.83         -93.91      -134.83
# 123       -58.36         -58.92       -94.31         -95.13      -136.44
# 124       -59.00         -59.26       -94.97         -95.51      -137.28
#
#      0.600_0.400.1  0.501_0.499  0.400_0.600  Target  Unnamed: 9
# ...

# %%
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]
df
# Out:
#      0.799_0.201  0.799_0.201.1  0.700_0.300  0.700_0.300.1  0.600_0.400  \
# 0         -10.06         -10.62       -14.43         -18.31       -24.64
# 1          -9.69         -10.86       -16.73         -21.75       -28.47
# 2         -12.07         -14.28       -21.54         -27.92       -35.19
# 3         -14.21         -17.41       -25.91         -33.36       -41.29
# 4         -16.57         -20.35       -29.97         -37.84       -47.03
# ..           ...            ...          ...            ...          ...
# 120       -54.35         -56.09       -88.23         -90.54      -128.65
# 121       -56.14         -57.35       -90.74         -92.60      -132.16
# 122       -57.71         -58.37       -92.83         -93.91      -134.83
# 123       -58.36         -58.92       -94.31         -95.13      -136.44
# 124       -59.00         -59.26       -94.97         -95.51      -137.28
#
#      0.600_0.400.1  0.501_0.499  0.400_0.600  Target
# ...

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
y = df['Target']
x = df.drop(['Target'], axis=1)

# %% [markdown]
# ### Memisahkan Data menjadi Data Latih dan Data Uji

# %% [markdown]
# ### Melatih Model MLPClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.2, random_state=27)

# %%
clf = MLPClassifier(hidden_layer_sizes=(300,300,300), max_iter=1000, alpha=0.0001,
                     solver='sgd', verbose=10,  random_state=21,tol=0.001)

# %% [markdown]
# ### Menguji Model Dan Untuk Menghitung Akurasi

# %%
clf.fit(x_train, y_train)
y_pred=clf.predict(x_test)
# Out:
# Iteration 1, loss = 11.47581549
# Iteration 2, loss = 18.31548573
# Iteration 3, loss = 20.12503510
# Iteration 4, loss = 23.68873043
# Iteration 5, loss = 15.93213762
# Iteration 6, loss = 3.37109763
# Iteration 7, loss = 3.96508968
# Iteration 8, loss = 7.77465123
# Iteration 9, loss = 8.02521459
# Iteration 10, loss = 3.96425256
# Iteration 11, loss = 4.04410424
# Iteration 12, loss = 4.41836985
# Iteration 13, loss = 3.56699415
# Iteration 14, loss = 2.25508926
# Iteration 15, loss = 2.95197170
# Iteration 16, loss = 2.58600661
# Iteration 17, loss = 1.85674972
# Iteration 18, loss = 1.84680679
# Iteration 19, loss = 1.69676900
# Iteration 20, loss = 1.38883444
# Iteration 21, loss = 1.35601676
# Iteration 22, loss = 1.29812496
# Iteration 23, loss = 1.27738671
# Iteration 24, loss = 1.25405833
# Iteration 25, loss = 1.23931890
# Iteration 26, loss = 1.21412291
# Iteration 27, loss = 1.19938223
# Iteration 28, loss = 1.18695774
# Iteration 29, loss = 1.17982885
# ...

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.6

# %%
print(y_test, y_pred)
# Out:
# 67     4
# 118    4
# 57     2
# 74     5
# 80     2
# 91     4
# 9      2
# 65     4
# 12     3
# 40     4
# 47     5
# 30     2
# 87     3
# 27     1
# 6      2
# 70     5
# 75     1
# 89     3
# 120    5
# 99     5
# 107    2
# 108    2
# 0      1
# 58     2
# 18     4
# Name: Target, dtype: int64 [4 4 4 3 2 4 4 4 4 4 5 2 2 1 4 3 1 4 5 2 2 2 1 4 4]

# %%
import pickle
with open('mlpku','wb') as f:
    pickle.dump(clf,f)

# %%
import joblib
with open('mlpku', 'rb') as f:
    clfuji = joblib.load(f)

# %%
uji = pd.read_csv('https://raw.githubusercontent.com/AnggaCristanto/dataset/main/uji-2.csv', sep = ';')
uji
# Out:
#    0.799_0.201  0.799_0.201.1  0.700_0.300  0.700_0.300.1  0.600_0.400  \
# 0       -14.21         -17.41       -25.91         -33.36       -41.29
# 1       -16.57         -20.35       -29.97         -37.84       -47.03
# 2       -79.62         -66.85      -126.61        -104.38      -162.73
# 3       -88.03         -76.88      -128.47        -124.36      -177.13
# 4       -91.08         -79.42      -131.32        -125.91      -182.66
# 5       -67.95         -76.82       -95.08        -105.21      -123.29
# 6       -67.29         -75.99       -94.75        -104.77      -118.70
# 7       -66.51         -73.04      -104.47        -113.72      -154.30
# 8       -66.68         -73.19      -105.21        -113.27      -154.42
#
#    0.600_0.400.1  0.501_0.499  0.400_0.600
# 0         -51.27       -59.94       -81.51
# 1         -57.29       -67.13       -90.01
# 2        -133.26      -194.87      -221.33
# 3        -175.21      -220.91      -274.27
# ...

# %%
y_pred=clfuji.predict(uji)

# %%
y_pred
# Out:
# array([1, 1, 4, 3, 3, 4, 4, 3, 3])
