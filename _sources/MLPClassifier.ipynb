# %% [markdown]
# # MLPClasssifier Dataset Alkhohol

# %% [markdown]
# ### Masukkan librari

# %%
import numpy as np # linear algebra
import pandas as pd 
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %% [markdown]
# ### Load File Dataset Iris Dengan CSV

# %%
df = pd.read_csv('https://raw.githubusercontent.com/AnggaCristanto/dataset/main/alkhohol2.csv', sep = ';')
df
# Out:
#      0.799_0.201  0.799_0.201.1  0.700_0.300  0.700_0.300.1  0.600_0.400  \
# 0         -10.06         -10.62       -14.43         -18.31       -24.64
# 1          -9.69         -10.86       -16.73         -21.75       -28.47
# 2         -12.07         -14.28       -21.54         -27.92       -35.19
# 3         -14.21         -17.41       -25.91         -33.36       -41.29
# 4         -16.57         -20.35       -29.97         -37.84       -47.03
# ..           ...            ...          ...            ...          ...
# 120       -54.35         -56.09       -88.23         -90.54      -128.65
# 121       -56.14         -57.35       -90.74         -92.60      -132.16
# 122       -57.71         -58.37       -92.83         -93.91      -134.83
# 123       -58.36         -58.92       -94.31         -95.13      -136.44
# 124       -59.00         -59.26       -94.97         -95.51      -137.28
#
#      0.600_0.400.1  0.501_0.499  0.501_0.499.1  0.400_0.600  0.400_0.600.1  \
# 0           -30.56       -38.62         -45.59       -54.89         -62.28
# 1           -35.83       -43.65         -52.43       -61.92         -71.27
# 2           -43.94       -52.04         -62.49       -71.97         -83.10
# 3           -51.27       -59.94         -71.55       -81.51         -93.83
# 4           -57.29       -67.13         -78.96       -90.01        -102.65
# ..             ...          ...            ...          ...            ...
# 120        -132.19      -173.71        -179.36      -231.30        -239.19
# 121        -135.36      -178.79        -183.93      -239.06        -246.53
# 122        -137.56      -182.33        -187.16      -243.12        -250.30
# 123        -138.96      -184.70        -189.32      -246.15        -252.80
# 124        -139.36      -186.98        -191.19      -248.98        -255.23
#
#      Target
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ..      ...
# 120       5
# 121       5
# 122       5
# 123       5
# 124       5
#
# [125 rows x 11 columns]

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

# %%
y = df['Target']
x = df.drop(['Target'], axis=1)

# %% [markdown]
# ### Memisahkan Data menjadi Data Latih dan Data Uji

# %% [markdown]
# ### Melatih Model MLPClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size= 0.2, random_state=27)

# %%
clf = MLPClassifier(hidden_layer_sizes=(300,300,300), max_iter=1000, alpha=0.0001,
                     solver='sgd', verbose=10,  random_state=21,tol=0.001)

# %% [markdown]
# ### Menguji Model Dan Untuk Menghitung Akurasi

# %%
clf.fit(x_train, y_train)
y_pred=clf.predict(x_test)
# Out:
# Iteration 1, loss = 13.46196001
# Iteration 2, loss = 21.77581266
# Iteration 3, loss = 27.78962069
# Iteration 4, loss = 22.85419894
# Iteration 5, loss = 16.48741904
# Iteration 6, loss = 10.14121838
# Iteration 7, loss = 14.70300731
# Iteration 8, loss = 13.42311912
# Iteration 9, loss = 11.23464314
# Iteration 10, loss = 7.07767980
# Iteration 11, loss = 7.42327904
# Iteration 87, loss = 0.86505213
# Iteration 88, loss = 0.86151726
# Iteration 89, loss = 0.84740032
# Iteration 90, loss = 0.84838438
# Iteration 91, loss = 0.83950041
# Iteration 92, loss = 0.86153411
# Iteration 93, loss = 0.83893693
# Iteration 94, loss = 0.84447531
# Iteration 95, loss = 0.84622330
# Iteration 96, loss = 0.89614986
# Iteration 97, loss = 0.95169238
# Iteration 98, loss = 0.98987356
# Iteration 99, loss = 1.00399018
# Iteration 100, loss = 0.99998624
# Iteration 101, loss = 0.92309980
# Iteration 102, loss = 0.93080326
# Training loss did not improve more than tol=0.001000 for 10 consecutive epochs. Stopping.

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.64

# %%
print(y_test, y_pred)
# Out:
# 67     4
# 118    4
# 57     2
# 74     5
# 80     2
# 91     4
# 9      2
# 65     4
# 12     3
# 40     4
# 47     5
# 30     2
# 87     3
# 27     1
# 6      2
# 70     5
# 75     1
# 89     3
# 120    5
# 99     5
# 107    2
# 108    2
# 0      1
# 58     2
# 18     4
# Name: Target, dtype: int64 [4 2 2 5 2 4 2 4 3 3 5 5 2 1 3 5 5 2 5 2 5 2 1 2 4]

# %%
import pickle
with open('mlpku','wb') as f:
    pickle.dump(clf,f)

# %%
import joblib
with open('mlpku', 'rb') as f:
    clfuji = joblib.load(f)

# %%
uji = pd.read_csv('https://raw.githubusercontent.com/AnggaCristanto/dataset/main/ujialkhohol.csv', sep = ';')
uji
# Out:
#    0.799_0.201  0.799_0.201.1  0.700_0.300  0.700_0.300.1  0.600_0.400  \
# 0       -14.21         -17.41       -25.91         -33.36       -41.29
# 1       -16.57         -20.35       -29.97         -37.84       -47.03
# 2       -79.62         -66.85      -126.61        -104.38      -162.73
# 3       -88.03         -76.88      -128.47        -124.36      -177.13
# 4       -91.08         -79.42      -131.32        -125.91      -182.66
# 5       -67.95         -76.82       -95.08        -105.21      -123.29
# 6       -67.29         -75.99       -94.75        -104.77      -118.70
# 7       -66.51         -73.04      -104.47        -113.72      -154.30
# 8       -66.68         -73.19      -105.21        -113.27      -154.42
#
#    0.600_0.400.1  0.501_0.499  0.501_0.499.1  0.400_0.600  0.400_0.600.1
# 0         -51.27       -59.94         -71.55       -81.51         -93.83
# 1         -57.29       -67.13         -78.96       -90.01        -102.65
# 2        -133.26      -194.87        -160.68      -221.33        -183.81
# 3        -175.21      -220.91        -218.92      -274.27        -268.55
# 4        -178.76      -224.73        -221.49      -272.67        -266.15
# 5        -132.91      -146.27        -153.75      -176.94        -184.07
# 6        -128.29      -142.31        -150.07      -172.51        -180.33
# 7        -162.43      -216.46        -217.99      -267.13        -269.45
# 8        -161.48      -215.52        -216.68      -262.01        -263.28

# %%
y_pred=clfuji.predict(uji)

# %%
y_pred
# Out:
# array([1, 1, 2, 3, 3, 4, 4, 5, 5])
